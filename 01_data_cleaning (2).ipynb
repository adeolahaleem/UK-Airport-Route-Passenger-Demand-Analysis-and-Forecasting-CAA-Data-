# %%
import pandas as pd

table1 = pd.read_csv("Table_01_Size_of_UK_Airports-Cleaned.csv")
table10_2 = pd.read_csv("Table_10_2_Domestic_Terminal_Pax-Cleaned.csv")
table12_2 = pd.read_csv("Table_12_2_Domestic_Route_Pax-Cleaned.csv")
table12_3 = pd.read_csv("Table_12_3_Route_Pax_By_Airport-Cleaned.csv")

print("Table_01_Size_of_UK_Airports-Cleaned")
print("Table_10_2_Domestic_Terminal_Pax-Cleaned")
print("Table_12_2_Domestic_Route_Pax-Cleaned")
print("Table_12_3_Route_Pax_By_Airport-Cleaned")
# Out:
# Table_01_Size_of_UK_Airports-Cleaned
# Table_10_2_Domestic_Terminal_Pax-Cleaned
# Table_12_2_Domestic_Route_Pax-Cleaned
# Table_12_3_Route_Pax_By_Airport-Cleaned

# %%
table1.rename(columns={
    'pax_total this_year_total_pax': 'this_year_total_pax',
    'airport_name': 'airport_name',
    'Airport Year': 'year'
}, inplace=True)

print(table1.columns)
# Out:
# Index(['rundate', 'year', 'airport_name', 'pax_current', 'pax_total',
#        'pax_5y_prev', 'pax_5y_prev_total', 'growth_5y_pct', 'cagr_5y'],
#       dtype='object')

# %%
def classify_airport(pax):
    if pax > 25000000:
        return "Large"
    elif pax > 5000000:
        return "Medium"
    else:
        return "Small"

table1['airport_size'] = table1['pax_total'].apply(classify_airport)

print(table1[['airport_name', 'pax_total', 'airport_size']].head())
# Out:
#   airport_name  pax_total airport_size
# 0     HEATHROW  272829990        Large
# 1      GATWICK  272829990        Large
# 2   MANCHESTER  272829990        Large
# 3     STANSTED  272829990        Large
# 4        LUTON  272829990        Large

# %%
import pandas as pd
import matplotlib.pyplot as plt

table1 = pd.read_csv("Table_01_Size_of_UK_Airports-Cleaned.csv")

def classify_airport(pax):
    if pax > 25000000:
        return "Large"
    elif pax > 5000000:
        return "Medium"
    else:
        return "Small"

table1['airport_size'] = table1['pax_total'].apply(classify_airport)

print(table1[['airport_name', 'pax_total', 'airport_size']].head())


colors = {'Large': 'red', 'Medium': 'blue', 'Small': 'green'}
table1['color'] = table1['airport_size'].map(colors)

plt.figure(figsize=(10,6))
plt.scatter(
    table1['pax_total'],
    table1['growth_5y_pct'],
    c=table1['color'],
    s=100
)

plt.title("5-Year Passenger Growth vs Airport Size")
plt.xlabel("Passenger Volume This Year")
plt.ylabel("5-Year Growth (%)")

for size in colors:
    plt.scatter([], [], c=colors[size], label=size)
plt.legend(title='Airport Size')

plt.grid(True)
plt.show()

table1['rank_growth'] = table1['growth_5y_pct'].rank(ascending=False)
top_growth_airports = table1.sort_values(by='growth_5y_pct', ascending=False).head(10)

print("Top 10 Airports by 5-Year Growth:")
print(top_growth_airports[['airport_name', 'pax_total', 'growth_5y_pct', 'cagr_5y', 'airport_size']])
# Out:
#   airport_name  pax_total airport_size
# 0     HEATHROW  272829990        Large
# 1      GATWICK  272829990        Large
# 2   MANCHESTER  272829990        Large
# 3     STANSTED  272829990        Large
# 4        LUTON  272829990        Large
# Top 10 Airports by 5-Year Growth:
#             airport_name  pax_total  growth_5y_pct  cagr_5y airport_size
# 0               HEATHROW  272829990            NaN      NaN        Large
# 1                GATWICK  272829990            NaN      NaN        Large
# 2             MANCHESTER  272829990            NaN      NaN        Large
# 3               STANSTED  272829990            NaN      NaN        Large
# 4                  LUTON  272829990            NaN      NaN        Large
# 5              EDINBURGH  272829990            NaN      NaN        Large
# 6             BIRMINGHAM  272829990            NaN      NaN        Large
# 7                BRISTOL  272829990            NaN      NaN        Large
# 8                GLASGOW  272829990            NaN      NaN        Large
# 9  BELFAST INTERNATIONAL  272829990            NaN      NaN        Large

# %%
table1 = pd.read_csv("Table_01_Size_of_UK_Airports-Cleaned.csv")

table1['growth_5y_pct'] = ((table1['pax_total'] - table1['pax_5y_prev_total']) / table1['pax_5y_prev_total']) * 100

table1['cagr_5y'] = ((table1['pax_total'] / table1['pax_5y_prev_total']) ** (1/5) - 1) * 100

print(table1[['airport_name','pax_total','pax_5y_prev_total','growth_5y_pct','cagr_5y']].head())
# Out:
#   airport_name  pax_total  pax_5y_prev_total  growth_5y_pct   cagr_5y
# 0     HEATHROW  272829990          292244892      -6.643367 -1.365457
# 1      GATWICK  272829990          292244892      -6.643367 -1.365457
# 2   MANCHESTER  272829990          292244892      -6.643367 -1.365457
# 3     STANSTED  272829990          292244892      -6.643367 -1.365457
# 4        LUTON  272829990          292244892      -6.643367 -1.365457

# %%
table1['pax_total'].nunique()
# Out:
# 1

# %%
table1.groupby('airport_name')['pax_total'].nunique()
# Out:
# airport_name
# ABERDEEN                          1
# BARRA                             1
# BELFAST CITY (GEORGE BEST)        1
# BELFAST INTERNATIONAL             1
# BENBECULA                         1
# BIGGIN HILL                       1
# BIRMINGHAM                        1
# BLACKPOOL                         1
# BOURNEMOUTH                       1
# BRISTOL                           1
# CAMPBELTOWN                       1
# CARDIFF WALES                     1
# CITY OF DERRY (EGLINTON)          1
# DONCASTER SHEFFIELD               1
# DUNDEE                            1
# EAST MIDLANDS INTERNATIONAL       1
# EDINBURGH                         1
# EXETER                            1
# FARNBOROUGH                       1
# GATWICK                           1
# GLASGOW                           1
# HEATHROW                          1
# HUMBERSIDE                        1
# INVERNESS                         1
# ISLAY                             1
# ISLES OF SCILLY (ST.MARYS)        1
# KIRKWALL                          1
# LANDS END (ST JUST)               1
# LEEDS BRADFORD                    1
# LERWICK (TINGWALL)                1
# LIVERPOOL (JOHN LENNON)           1
# LONDON CITY                       1
# LUTON                             1
# LYDD                              1
# MANCHESTER                        1
# NEWCASTLE                         1
# NEWQUAY                           1
# NORWICH                           1
# OXFORD (KIDLINGTON)               1
# PRESTWICK                         1
# SCATSTA                           1
# SOUTHAMPTON                       1
# SOUTHEND                          1
# STANSTED                          1
# STORNOWAY                         1
# SUMBURGH                          1
# TEESSIDE INTERNATIONAL AIRPORT    1
# TIREE                             1
# WICK JOHN O GROATS                1
# Name: pax_total, dtype: int64

# %%
table1[['airport_name', 'pax_current']].head(10)
# Out:
#             airport_name  pax_current
# 0               HEATHROW     79149042
# 1                GATWICK     40894242
# 2             MANCHESTER     28077659
# 3               STANSTED     27951116
# 4                  LUTON     16399866
# 5              EDINBURGH     14395463
# 6             BIRMINGHAM     11479335
# 7                BRISTOL      9911879
# 8                GLASGOW      7355987
# 9  BELFAST INTERNATIONAL      5956888

# %%
table1['pax_current'].nunique()
# Out:
# 48

# %%
table1['growth_5y_pct'] = (
    (table1['pax_current'] - table1['pax_5y_prev']) 
    / table1['pax_5y_prev']
) * 100

table1['cagr_5y'] = (
    (table1['pax_current'] / table1['pax_5y_prev']) ** (1/5) - 1
) * 100

# %%
table1[['airport_name','pax_current','pax_5y_prev','growth_5y_pct','cagr_5y']].head()
# Out:
#   airport_name  pax_current  pax_5y_prev  growth_5y_pct   cagr_5y
# 0     HEATHROW     79149042     80100311      -1.187597 -0.238656
# 1      GATWICK     40894242     46081327     -11.256371 -2.360075
# 2   MANCHESTER     28077659     28254970      -0.627539 -0.125824
# 3     STANSTED     27951116     27995121      -0.157188 -0.031457
# 4        LUTON     16399866     16766552      -2.187009 -0.441279

# %%
def classify_airport(pax):
    if pax >= 25_000_000:
        return "Large"
    elif pax >= 5_000_000:
        return "Medium"
    else:
        return "Small"

table1['airport_size'] = table1['pax_current'].apply(classify_airport)

# %%
table1.head()
# Out:
#             rundate  year airport_name  pax_current  pax_total  pax_5y_prev  \
# 0  19/03/2024 12:52  2023     HEATHROW     79149042  272829990     80100311
# 1  19/03/2024 12:52  2023      GATWICK     40894242  272829990     46081327
# 2  19/03/2024 12:52  2023   MANCHESTER     28077659  272829990     28254970
# 3  19/03/2024 12:52  2023     STANSTED     27951116  272829990     27995121
# 4  19/03/2024 12:52  2023        LUTON     16399866  272829990     16766552
#
#    pax_5y_prev_total  growth_5y_pct  cagr_5y airport_size color  rank_growth
# 0          292244892            NaN      NaN        Large   red          NaN
# 1          292244892            NaN      NaN        Large   red          NaN
# 2          292244892            NaN      NaN        Large   red          NaN
# 3          292244892            NaN      NaN        Large   red          NaN
# 4          292244892            NaN      NaN        Large   red          NaN

# %%
table1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rundate            49 non-null     object
#  1   year               49 non-null     int64
#  2   airport_name       49 non-null     object
#  3   pax_current        49 non-null     int64
#  4   pax_total          49 non-null     int64
#  5   pax_5y_prev        49 non-null     int64
#  6   pax_5y_prev_total  49 non-null     int64
#  7   growth_5y_pct      0 non-null      float64
#  8   cagr_5y            0 non-null      float64
#  9   airport_size       49 non-null     object
#  10  color              49 non-null     object
#  11  rank_growth        0 non-null      float64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.9+ KB

# %%
table1.groupby('airport_name')['year'].nunique().sort_values(ascending=False).head(10)
# Out:
# airport_name
# ABERDEEN                      1
# ISLES OF SCILLY (ST.MARYS)    1
# LANDS END (ST JUST)           1
# LEEDS BRADFORD                1
# LERWICK (TINGWALL)            1
# LIVERPOOL (JOHN LENNON)       1
# LONDON CITY                   1
# LUTON                         1
# LYDD                          1
# MANCHESTER                    1
# Name: year, dtype: int64

# %%
table1['growth_5y_pct'] = (
    (table1['pax_current'] - table1['pax_5y_prev'])
    / table1['pax_5y_prev']
) * 100

# %%
table1[['airport_name','pax_current','pax_5y_prev','growth_5y_pct']].head()
# Out:
#   airport_name  pax_current  pax_5y_prev  growth_5y_pct
# 0     HEATHROW     79149042     80100311      -1.187597
# 1      GATWICK     40894242     46081327     -11.256371
# 2   MANCHESTER     28077659     28254970      -0.627539
# 3     STANSTED     27951116     27995121      -0.157188
# 4        LUTON     16399866     16766552      -2.187009

# %%
table1['cagr_5y'] = (
    (table1['pax_current'] / table1['pax_5y_prev']) ** (1/5) - 1
) * 100

# %%
table1[['airport_name','growth_5y_pct','cagr_5y']].head()
# Out:
#   airport_name  growth_5y_pct   cagr_5y
# 0     HEATHROW      -1.187597 -0.238656
# 1      GATWICK     -11.256371 -2.360075
# 2   MANCHESTER      -0.627539 -0.125824
# 3     STANSTED      -0.157188 -0.031457
# 4        LUTON      -2.187009 -0.441279

# %%
table1.sort_values('cagr_5y', ascending=False).head(10)
# Out:
#              rundate  year                    airport_name  pax_current  \
# 34  19/03/2024 12:52  2023                     FARNBOROUGH        38827
# 43  19/03/2024 12:52  2023                     BIGGIN HILL         6495
# 26  19/03/2024 12:52  2023  TEESSIDE INTERNATIONAL AIRPORT       226326
# 35  19/03/2024 12:52  2023                          DUNDEE        32862
# 17  19/03/2024 12:52  2023                     BOURNEMOUTH       950028
# 7   19/03/2024 12:52  2023                         BRISTOL      9911879
# 25  19/03/2024 12:52  2023                        SUMBURGH       258478
# 5   19/03/2024 12:52  2023                       EDINBURGH     14395463
# 3   19/03/2024 12:52  2023                        STANSTED     27951116
# 2   19/03/2024 12:52  2023                      MANCHESTER     28077659
#
#     pax_total  pax_5y_prev  pax_5y_prev_total  growth_5y_pct    cagr_5y  \
# 34  272829990            0          292244892            inf        inf
# 43  272829990         1674          292244892     287.992832  31.148927
# 26  272829990       139549          292244892      62.183892  10.154323
# 35  272829990        21185          292244892      55.119188   9.177490
# 17  272829990       674972          292244892      40.750727   7.075505
# 7   272829990      8696653          292244892      13.973491   2.650429
# 25  272829990       245766          292244892       5.172400   1.013718
# 5   272829990     14291811          292244892       0.725254   0.144632
# 3   272829990     27995121          292244892      -0.157188  -0.031457
# 2   272829990     28254970          292244892      -0.627539  -0.125824
#
#    airport_size color  rank_growth
# 34        Large   red          NaN
# 43        Large   red          NaN
# 26        Large   red          NaN
# 35        Large   red          NaN
# 17        Large   red          NaN
# 7         Large   red          NaN
# 25        Large   red          NaN
# 5         Large   red          NaN
# 3         Large   red          NaN
# 2         Large   red          NaN

# %%
table1.sort_values('cagr_5y').head(10)
# Out:
#              rundate  year         airport_name  pax_current  pax_total  \
# 48  19/03/2024 12:52  2023              SCATSTA            0  272829990
# 47  19/03/2024 12:52  2023  DONCASTER SHEFFIELD            0  272829990
# 46  19/03/2024 12:52  2023  OXFORD (KIDLINGTON)            2  272829990
# 45  19/03/2024 12:52  2023                 LYDD            7  272829990
# 28  19/03/2024 12:52  2023             SOUTHEND       146072  272829990
# 20  19/03/2024 12:52  2023          SOUTHAMPTON       754678  272829990
# 22  19/03/2024 12:52  2023               EXETER       433067  272829990
# 18  19/03/2024 12:52  2023        CARDIFF WALES       837252  272829990
# 41  19/03/2024 12:52  2023   WICK JOHN O GROATS        10719  272829990
# 24  19/03/2024 12:52  2023              NORWICH       357852  272829990
#
#     pax_5y_prev  pax_5y_prev_total  growth_5y_pct     cagr_5y airport_size  \
# 48       174934          292244892    -100.000000 -100.000000        Large
# 47      1222295          292244892    -100.000000 -100.000000        Large
# 46          100          292244892     -98.000000  -54.269495        Large
# 45          284          292244892     -97.535211  -52.317838        Large
# 28      1480139          292244892     -90.131197  -37.070701        Large
# 20      1990930          292244892     -62.094197  -17.635296        Large
# 22       931182          292244892     -53.492765  -14.196678        Large
# 18      1579204          292244892     -46.982657  -11.918725        Large
# 41        16756          292244892     -36.028885   -8.547247        Large
# 24       536578          292244892     -33.308485   -7.782336        Large
#
#    color  rank_growth
# 48   red          NaN
# 47   red          NaN
# 46   red          NaN
# 45   red          NaN
# 28   red          NaN
# 20   red          NaN
# 22   red          NaN
# 18   red          NaN
# 41   red          NaN
# 24   red          NaN

# %%
table1.columns
# Out:
# Index(['rundate', 'year', 'airport_name', 'pax_current', 'pax_5y_prev',
#        'growth_5y_pct', 'cagr_5y', 'airport_size', 'color', 'rank_growth'],
#       dtype='object')

# %%
table1 = table1.drop(
    columns=['pax_total', 'pax_5y_prev_total'],
    errors='ignore'
)

# %%
def classify_airport(pax):
    if pax >= 25_000_000:
        return 'Large'
    elif pax >= 5_000_000:
        return 'Medium'
    else:
        return 'Small'

table1['airport_size'] = table1['pax_current'].apply(classify_airport)

# %%
table1[['airport_name','pax_current','airport_size']].sort_values('pax_current', ascending=False).head(12)
# Out:
#                airport_name  pax_current airport_size
# 0                  HEATHROW     79149042        Large
# 1                   GATWICK     40894242        Large
# 2                MANCHESTER     28077659        Large
# 3                  STANSTED     27951116        Large
# 4                     LUTON     16399866       Medium
# 5                 EDINBURGH     14395463       Medium
# 6                BIRMINGHAM     11479335       Medium
# 7                   BRISTOL      9911879       Medium
# 8                   GLASGOW      7355987       Medium
# 9     BELFAST INTERNATIONAL      5956888       Medium
# 10                NEWCASTLE      4818885        Small
# 11  LIVERPOOL (JOHN LENNON)      4193076        Small

# %%
table10_2['scheduled_share'] = (table10_2['scheduled_pax'] / table10_2['total_domestic_pax']) * 100
table10_2['charter_share'] = (table10_2['charter_pax'] / table10_2['total_domestic_pax']) * 100

# %%
table10_2 = table10_2.merge(
    table1[['airport_name','airport_size']],
    left_on='airport_name',
    right_on='airport_name',
    how='left'
)

# %%
table10_2[['airport_name','airport_size','scheduled_share','charter_share']].head(12)
# Out:
#                   airport_name airport_size  scheduled_share  charter_share
# 0                      GATWICK        Large        99.985269       0.014731
# 1                     HEATHROW        Large        99.997954       0.002046
# 2                  LONDON CITY        Small        99.986007       0.013993
# 3                        LUTON       Medium        99.988815       0.011185
# 4                     SOUTHEND        Small        22.413793      77.586207
# 5                     STANSTED        Large        99.978106       0.021894
# 6                     ABERDEEN        Small        97.228574       2.771426
# 7                        BARRA        Small       100.000000       0.000000
# 8   BELFAST CITY (GEORGE BEST)        Small        99.984421       0.015579
# 9        BELFAST INTERNATIONAL       Medium        99.948705       0.051295
# 10                   BENBECULA        Small       100.000000       0.000000
# 11                 BIGGIN HILL        Small         0.000000     100.000000

# %%
table10_2['charter_risk_flag'] = table10_2['charter_share'].apply(lambda x: 'High' if x > 30 else 'Low')

# %%
table10_2[['airport_name','airport_size','scheduled_share','charter_share','charter_risk_flag']].sort_values('charter_share', ascending=False).head(10)
# Out:
#                       airport_name airport_size  scheduled_share  \
# 23                     FARNBOROUGH        Small         0.000000
# 38                       PRESTWICK        Small         0.000000
# 11                     BIGGIN HILL        Small         0.000000
# 4                         SOUTHEND        Small        22.413793
# 41                        SUMBURGH        Small        79.131811
# 25                      HUMBERSIDE        Small        83.150206
# 42  TEESSIDE INTERNATIONAL AIRPORT        Small        92.980257
# 13                     BOURNEMOUTH        Small        96.310495
# 16                   CARDIFF WALES        Small        96.637005
# 6                         ABERDEEN        Small        97.228574
#
#     charter_share charter_risk_flag
# 23     100.000000              High
# 38     100.000000              High
# 11     100.000000              High
# 4       77.586207              High
# 41      20.868189               Low
# 25      16.849794               Low
# 42       7.019743               Low
# 13       3.689505               Low
# 16       3.362995               Low
# 6        2.771426               Low

# %%
import pandas as pd

table12_2 = pd.read_csv('Table_12_2_Domestic_Route_Pax-Cleaned.csv')
table12_3 = pd.read_csv('Table_12_3_Route_Pax_By_Airport-Cleaned.csv')

print(table12_2.head())
print(table12_3.head())
# Out:
#   origin_airport         destination_airport  pax_current  pax_previous  \
# 0        GATWICK                    ABERDEEN       194917        162333
# 1        GATWICK  BELFAST CITY (GEORGE BEST)       233493        165388
# 2        GATWICK       BELFAST INTERNATIONAL       484490        500189
# 3        GATWICK                  BIRMINGHAM          168           472
# 4        GATWICK                     BRISTOL          201           285
#
#    pax_growth_pct  scheduled_share  charter_share
# 0        20.07232              NaN            NaN
# 1        41.17892              NaN            NaN
# 2        -3.13861              NaN            NaN
# 3       -64.40678              NaN            NaN
# 4       -29.47368              NaN            NaN
#   reporting_airport                       route  pax_current  pax_growth_pct
# 0           GATWICK                    ABERDEEN       194917        20.07232
# 1           GATWICK  BELFAST CITY (GEORGE BEST)       233493        41.17892
# 2           GATWICK       BELFAST INTERNATIONAL       484490        -3.13861
# 3           GATWICK                  BIRMINGHAM          168       -64.40678
# 4           GATWICK                     BRISTOL          201       -29.47368

# %%
table12_3['route_share_pct'] = (table12_3['pax_current'] / table12_3.groupby('reporting_airport')['pax_current'].transform('sum')) * 100

# %%
top_routes = table12_3.sort_values(['reporting_airport', 'route_share_pct'], ascending=[True, False])
top_routes = top_routes.groupby('reporting_airport').head(3)  # Top 3 routes per airport
top_routes[['reporting_airport','route','pax_current','route_share_pct']]
# Out:
#       reporting_airport                route  pax_current  route_share_pct
# 107            ABERDEEN             HEATHROW       504448        42.446339
# 104            ABERDEEN              GATWICK       194377        16.355684
# 122            ABERDEEN             SUMBURGH       100792         8.481055
# 125            ALDERNEY             GUERNSEY        32228        65.046623
# 127            ALDERNEY          SOUTHAMPTON        17214        34.743471
# ..                  ...                  ...          ...              ...
# 722               TIREE              GLASGOW        11167        95.387375
# 724               TIREE  OBAN (NORTH CONNEL)          251         2.144016
# 720               TIREE                 COLL          194         1.657128
# 725  WICK JOHN O GROATS             ABERDEEN        10674        99.682480
# 726  WICK JOHN O GROATS          FARNBOROUGH           34         0.317520
#
# [136 rows x 4 columns]

# %%
table12_3['route_dependency_flag'] = table12_3['route_share_pct'].apply(lambda x: 'High' if x > 50 else 'Low')

# %%
table12_3.columns
# Out:
# Index(['reporting_airport', 'route', 'pax_current', 'pax_growth_pct',
#        'route_share_pct', 'route_dependency_flag'],
#       dtype='object')

# %%
table12_3['pax_previous'] = table12_3['pax_current'] / (1 + table12_3['pax_growth_pct']/100)

# %%
import numpy as np

table12_3['cagr_5y'] = table12_3['cagr_5y'].replace([np.inf, -np.inf], np.nan)

# %%
table12_3 = table12_3.merge(
    table1[['airport_name','airport_size']],
    left_on='reporting_airport',
    right_on='airport_name',
    how='left'
)

table12_3 = table12_3.drop(columns=['airport_name'])

# %%
portfolio_routes = table12_3[['reporting_airport','airport_size','route',
                               'pax_current','route_share_pct','route_dependency_flag','cagr_5y']]

portfolio_routes.sort_values(['airport_size','route_share_pct'], ascending=[False, False]).head(20)
# Out:
#                   reporting_airport airport_size                       route  \
# 128                           BARRA        Small                     GLASGOW
# 725              WICK JOHN O GROATS        Small                    ABERDEEN
# 455                           ISLAY        Small                     GLASGOW
# 253                     CAMPBELTOWN        Small                     GLASGOW
# 223                     BOURNEMOUTH        Small                   EDINBURGH
# 722                           TIREE        Small                     GLASGOW
# 652                       PRESTWICK        Small     LIVERPOOL (JOHN LENNON)
# 633                         NORWICH        Small                    ABERDEEN
# 176                       BENBECULA        Small                     GLASGOW
# 79                         SOUTHEND        Small     LIVERPOOL (JOHN LENNON)
# 700  TEESSIDE INTERNATIONAL AIRPORT        Small                    ABERDEEN
# 418                      HUMBERSIDE        Small                    ABERDEEN
# 513                  LEEDS BRADFORD        Small  BELFAST CITY (GEORGE BEST)
# 528              LERWICK (TINGWALL)        Small                   FAIR ISLE
# 289                          DUNDEE        Small                    HEATHROW
# 681                       STORNOWAY        Small                     GLASGOW
# 686                        SUMBURGH        Small                    ABERDEEN
# 257                   CARDIFF WALES        Small  BELFAST CITY (GEORGE BEST)
# 600                       NEWCASTLE        Small                    HEATHROW
# 533         LIVERPOOL (JOHN LENNON)        Small       BELFAST INTERNATIONAL
#
#      pax_current  route_share_pct route_dependency_flag     cagr_5y
# 128        12836        99.898825                  High   -0.409382
# 725        10674        99.682480                  High    8.957212
# 455        28761        99.429579                  High    2.157922
# 253         7004        99.038462                  High    4.173491
# 223        48192        95.632330                  High  317.482495
# 722        11167        95.387375                  High    1.127896
# 652           56        88.888889                  High    0.000000
# 633        32755        86.674076                  High    0.251621
# 176        25561        83.369211                  High    1.244641
# 79            45        77.586207                  High    0.000000
# 700        14286        74.616108                  High   -7.695981
# 418        11275        71.610035                  High    1.880791
# 513       113169        66.276046                  High    3.620830
# 528         1910        65.568143                  High    0.200149
# 289        18742        57.573803                  High    0.000000
# 681        59211        56.283686                  High   -0.831721
# 686        95752        52.811207                  High    0.619157
# 257        35639        51.517079                  High   20.180976
# 600       435542        48.505982                   Low    5.934418
# 533       395118        48.271363                   Low   -0.841901

# %%
table12_3['pax_forecast_next_year'] = table12_3['pax_current'] * (1 + table12_3['cagr_5y']/100)

# %%
table12_3['reporting_airport'] = table12_3['reporting_airport'].str.strip().str.upper()

# %%
total_pax_per_airport = table12_3.groupby('reporting_airport')['pax_current'].sum().reset_index()
total_pax_per_airport.rename(columns={'pax_current':'total_pax_airport'}, inplace=True)
total_pax_per_airport['reporting_airport'] = total_pax_per_airport['reporting_airport'].str.strip().str.upper()

# %%
table12_3 = table12_3.merge(total_pax_per_airport, on='reporting_airport', how='left')

# %%
print(table12_3.columns)
# Out:
# Index(['reporting_airport', 'route', 'pax_current', 'pax_growth_pct',
#        'pax_previous', 'cagr_5y', 'airport_size', 'total_pax_airport_x',
#        'route_share_pct', 'total_pax_airport_y', 'pax_forecast_next_year',
#        'total_pax_airport'],
#       dtype='object')

# %%
table12_3['route_share_pct'] = (table12_3['pax_current'] / table12_3['total_pax_airport']) * 100

# %%
table12_3['route_dependency_flag'] = np.where(table12_3['route_share_pct'] > 50, 'High', 'Low')

# %%
if 'total_pax_airport' in table12_3.columns:
    table12_3 = table12_3.drop(columns=['total_pax_airport'])

total_pax_per_airport = table12_3.groupby('reporting_airport')['pax_current'].sum().reset_index()
total_pax_per_airport.rename(columns={'pax_current':'total_pax_airport'}, inplace=True)

table12_3 = table12_3.merge(total_pax_per_airport, on='reporting_airport', how='left')

# %%
total_pax_per_airport = table12_3.groupby('reporting_airport')['pax_current'].sum().reset_index()
total_pax_per_airport.rename(columns={'pax_current':'total_pax_airport'}, inplace=True)

table12_3 = table12_3.merge(total_pax_per_airport, on='reporting_airport', how='left', suffixes=('', '_total'))

# %%
import pandas as pd
import numpy as np

# ---- Step 0: Make sure your dataframe is loaded ----
# Example:
# table12_3 = pd.read_csv('Table_12_3_Route_Pax_By_Airport-Cleaned.csv')

# ---- Step 1: Strip and uppercase airport names to avoid merge issues ----
table12_3['reporting_airport'] = table12_3['reporting_airport'].str.strip().str.upper()
table12_3['route'] = table12_3['route'].str.strip().str.upper()

# ---- Step 2: Calculate total passengers per reporting airport ----
# Drop old total_pax_airport if it exists
if 'total_pax_airport' in table12_3.columns:
    table12_3 = table12_3.drop(columns=['total_pax_airport'])

total_pax_per_airport = table12_3.groupby('reporting_airport')['pax_current'].sum().reset_index()
total_pax_per_airport.rename(columns={'pax_current':'total_pax_airport'}, inplace=True)

# Merge total passengers back into table12_3
table12_3 = table12_3.merge(total_pax_per_airport, on='reporting_airport', how='left')

# ---- Step 3: Calculate route share % ----
table12_3['route_share_pct'] = (table12_3['pax_current'] / table12_3['total_pax_airport']) * 100

# ---- Step 4: Flag high/low route dependency ----
table12_3['route_dependency_flag'] = np.where(table12_3['route_share_pct'] > 50, 'High', 'Low')

# ---- Step 5: Forecast next-year passengers per route using 5-year CAGR ----
# Make sure 'cagr_5y' exists (if not, you can set it to 0 for small airports)
if 'cagr_5y' not in table12_3.columns:
    table12_3['cagr_5y'] = 0

table12_3['pax_forecast_next_year'] = table12_3['pax_current'] * (1 + table12_3['cagr_5y']/100)

# ---- Step 6: Optional: sort by route dependency to highlight risk ----
table12_3 = table12_3.sort_values(['route_dependency_flag', 'route_share_pct'], ascending=[False, False])

# ---- Step 7: Inspect final table ----
print(table12_3.head(20))
# Out:
#                reporting_airport                       route  pax_current  \
# 600                    NEWCASTLE                    HEATHROW       435542
# 533      LIVERPOOL (JOHN LENNON)       BELFAST INTERNATIONAL       395118
# 48                   LONDON CITY                   EDINBURGH       342810
# 409                     GUERNSEY                     GATWICK       307327
# 86                      STANSTED                   EDINBURGH       599950
# 107                     ABERDEEN                    HEATHROW       504448
# 281     CITY OF DERRY (EGLINTON)                  MANCHESTER        56967
# 81                      STANSTED       BELFAST INTERNATIONAL       489477
# 127                     ALDERNEY                 SOUTHAMPTON        17214
# 616                      NEWQUAY                     GATWICK        84025
# 529           LERWICK (TINGWALL)                       FOULA         1003
# 196                   BIRMINGHAM       BELFAST INTERNATIONAL       348990
# 295  EAST MIDLANDS INTERNATIONAL       BELFAST INTERNATIONAL        39785
# 576                   MANCHESTER                    HEATHROW       573029
# 499                     KIRKWALL                    ABERDEEN        42821
# 442                    INVERNESS                     GATWICK       222505
# 279     CITY OF DERRY (EGLINTON)                    HEATHROW        46760
# 294  EAST MIDLANDS INTERNATIONAL  BELFAST CITY (GEORGE BEST)        37276
# 237                      BRISTOL                   EDINBURGH       422825
# 625                      NEWQUAY                  MANCHESTER        72686
#
#      pax_growth_pct   pax_previous    cagr_5y airport_size  \
# 600        33.40909  326471.007335   5.934418       Medium
# 533        -4.13922  412178.995414  -0.841901       Medium
# 48         12.75347  304034.988901   2.429719       Medium
# 409         9.29903  281179.988514   1.794253          NaN
# 86        125.69444  265824.005235  17.680410        Large
# 107        23.27814  409195.012190   4.274284        Small
# 281         3.87098   54843.999739   0.762480        Small
# 81         67.03932  293031.006113  10.806119        Large
# 127         0.80225   17076.999769   0.159938          NaN
# 616        29.68622   64791.000925   5.336471        Small
# 529         1.21090     990.999981   0.241015        Small
# 196        11.19891  313843.004396   2.145704        Large
# 295       265.63735   10880.999985  29.601525       Medium
# 576        40.41731  408089.999730   7.024727        Large
# 499         4.56133   40952.998589   0.896063        Small
# 442         2.86965  216298.004319   0.567453        Small
# 279         0.00000   46760.000000   0.000000        Small
# 294       108.18766   17904.999749  15.795317       Medium
# 237        42.54915  296616.991403   7.347745       Medium
# 625        20.58663   60276.997541   3.814934        Small
#
#      total_pax_airport_x  route_share_pct  total_pax_airport_y  \
# 600               897914        48.505982               897914
# 533               818535        48.271363               818535
# 48                715746        47.895482               715746
# 409               670161        45.858682               670161
# 86               1369772        43.799260              1369772
# 107              1188437        42.446339              1188437
# 281               149911        38.000547               149911
# 81               1369772        35.734195              1369772
# 127                49546        34.743471                49546
# 616               242209        34.691114               242209
# 529                 2913        34.431857                 2913
# 196              1031390        33.836861              1031390
# 295               120527        33.009201               120527
# 576              1768040        32.410409              1768040
# 499               133629        32.044691               133629
# 442               709593        31.356707               709593
# 279               149911        31.191840               149911
# 294               120527        30.927510               120527
# 237              1367422        30.921325              1367422
# 625               242209        30.009620               242209
#
#      pax_forecast_next_year route_dependency_flag  total_pax_airport_total  \
# 600           461388.882238                   Low                   897914
# 533           391791.497198                   Low                   818535
# 48            351139.321275                   Low                   715746
# 409           312841.225230                   Low                   670161
# 86            706023.618587                   Low                  1369772
# 107           526009.537969                   Low                  1188437
# 281            57401.361699                   Low                   149911
# 81            542370.465542                   Low                  1369772
# 127            17241.531655                   Low                    49546
# 616            88508.970151                   Low                   242209
# 529             1005.417385                   Low                     2913
# 196           356478.292437                   Low                  1031390
# 295            51561.966567                   Low                   120527
# 576           613282.724406                   Low                  1768040
# 499            43204.703088                   Low                   133629
# 442           223767.611937                   Low                   709593
# 279            46760.000000                   Low                   149911
# 294            43163.862442                   Low                   120527
# 237           453893.103362                   Low                  1367422
# 625            75458.922832                   Low                   242209
#
#      total_pax_airport_total  total_pax_airport
# 600                   897914             897914
# 533                   818535             818535
# 48                    715746             715746
# 409                   670161             670161
# 86                   1369772            1369772
# 107                  1188437            1188437
# 281                   149911             149911
# 81                   1369772            1369772
# 127                    49546              49546
# 616                   242209             242209
# 529                     2913               2913
# 196                  1031390            1031390
# 295                   120527             120527
# 576                  1768040            1768040
# 499                   133629             133629
# 442                   709593             709593
# 279                   149911             149911
# 294                   120527             120527
# 237                  1367422            1367422
# 625                   242209             242209

# %%
# ---- Step 1: Keep only one total_pax_airport column ----
# Drop all duplicates of total_pax_airport
cols_to_drop = [col for col in table12_3.columns if 'total_pax_airport' in col and col != 'total_pax_airport']
table12_3.drop(columns=cols_to_drop, inplace=True)

# ---- Step 2: Ensure total_pax_airport is correct ----
# If you want to recalc from scratch:
total_pax_per_airport = table12_3.groupby('reporting_airport')['pax_current'].sum().reset_index()
total_pax_per_airport.rename(columns={'pax_current':'total_pax_airport'}, inplace=True)
table12_3 = table12_3.drop(columns=['total_pax_airport'], errors='ignore')  # drop old column
table12_3 = table12_3.merge(total_pax_per_airport, on='reporting_airport', how='left')

# ---- Step 3: Recalculate route_share_pct ----
table12_3['route_share_pct'] = (table12_3['pax_current'] / table12_3['total_pax_airport']) * 100

# ---- Step 4: Recalculate route_dependency_flag ----
table12_3['route_dependency_flag'] = np.where(table12_3['route_share_pct'] > 50, 'High', 'Low')

# ---- Step 5: Optional: sort for inspection ----
table12_3 = table12_3.sort_values(['reporting_airport', 'route_share_pct'], ascending=[True, False])

# ---- Step 6: Inspect ----
table12_3[['reporting_airport','route','pax_current','total_pax_airport','route_share_pct','route_dependency_flag']].head(20)
# Out:
#     reporting_airport                           route  pax_current  \
# 5            ABERDEEN                        HEATHROW       504448
# 63           ABERDEEN                         GATWICK       194377
# 118          ABERDEEN                        SUMBURGH       100792
# 142          ABERDEEN                           LUTON        80144
# 151          ABERDEEN                      MANCHESTER        71549
# 174          ABERDEEN                      BIRMINGHAM        53421
# 184          ABERDEEN                        KIRKWALL        43291
# 200          ABERDEEN                         NORWICH        32898
# 238          ABERDEEN      BELFAST CITY (GEORGE BEST)        20359
# 254          ABERDEEN                         BRISTOL        16231
# 261          ABERDEEN                       NEWCASTLE        14397
# 262          ABERDEEN  TEESSIDE INTERNATIONAL AIRPORT        14293
# 269          ABERDEEN                         NEWQUAY        12412
# 278          ABERDEEN              WICK JOHN O GROATS        10785
# 280          ABERDEEN                      HUMBERSIDE        10737
# 316          ABERDEEN                     SOUTHAMPTON         6115
# 402          ABERDEEN                     LONDON CITY         1140
# 457          ABERDEEN                        GUERNSEY          358
# 489          ABERDEEN           BELFAST INTERNATIONAL          189
# 495          ABERDEEN         LIVERPOOL (JOHN LENNON)          177
#
#      total_pax_airport  route_share_pct route_dependency_flag
# 5              1188437        42.446339                   Low
# 63             1188437        16.355684                   Low
# 118            1188437         8.481055                   Low
# 142            1188437         6.743647                   Low
# 151            1188437         6.020429                   Low
# 174            1188437         4.495064                   Low
# 184            1188437         3.642684                   Low
# 200            1188437         2.768174                   Low
# 238            1188437         1.713090                   Low
# 254            1188437         1.365743                   Low
# 261            1188437         1.211423                   Low
# 262            1188437         1.202672                   Low
# 269            1188437         1.044397                   Low
# 278            1188437         0.907494                   Low
# 280            1188437         0.903456                   Low
# 316            1188437         0.514541                   Low
# 402            1188437         0.095924                   Low
# 457            1188437         0.030124                   Low
# 489            1188437         0.015903                   Low
# 495            1188437         0.014894                   Low

# %%
table12_3['pax_forecast_next_year'] = table12_3['pax_current'] * (1 + table12_3['cagr_5y']/100)

# %%
table12_3_sorted = table12_3.sort_values(['reporting_airport','route_share_pct'], ascending=[True, False])

# %%
# Step 1: Clean airport names (just to be sure)
table12_3['reporting_airport'] = table12_3['reporting_airport'].str.strip().str.upper()

# Step 2: Compute total passengers per airport
total_pax_per_airport = (
    table12_3.groupby('reporting_airport')['pax_current']
    .sum()
    .reset_index()
    .rename(columns={'pax_current': 'total_pax_airport'})
)

# Step 3: Merge total passengers back
table12_3 = table12_3.merge(total_pax_per_airport, on='reporting_airport', how='left', suffixes=('', '_total'))

# Step 4: Check what the column is actually called
print(table12_3.columns)  # Look for 'total_pax_airport' or 'total_pax_airport_total'

# Step 5: Use the correct column for route share
if 'total_pax_airport' in table12_3.columns:
    table12_3['route_share_pct'] = (table12_3['pax_current'] / table12_3['total_pax_airport']) * 100
elif 'total_pax_airport_total' in table12_3.columns:
    table12_3['route_share_pct'] = (table12_3['pax_current'] / table12_3['total_pax_airport_total']) * 100
else:
    raise ValueError("No column for total passengers found!")

# Step 6: Flag high/low dependency
table12_3['route_dependency_flag'] = np.where(table12_3['route_share_pct'] > 50, 'High', 'Low')
# Out:
# Index(['reporting_airport', 'route', 'pax_current', 'pax_growth_pct',
#        'pax_previous', 'cagr_5y', 'airport_size', 'route_share_pct',
#        'pax_forecast_next_year', 'route_dependency_flag',
#        'total_pax_airport_x', 'total_pax_airport_y', 'total_pax_airport'],
#       dtype='object')

# %%
# ---- Step: Calculate route share % ----
table12_3['route_share_pct'] = (table12_3['pax_current'] / table12_3['total_pax_airport']) * 100

# ---- Step: Flag High/Low route dependency ----
table12_3['route_dependency_flag'] = np.where(table12_3['route_share_pct'] > 50, 'High', 'Low')

# %%
table12_3.drop(columns=['total_pax_airport_x', 'total_pax_airport_y'], inplace=True)

# %%
# If you already loaded it from CSV or Excel:
import pandas as pd

table1_cleaned = pd.read_csv('Table_01_Size_of_UK_Airports-Cleaned.csv')  # or your actual file
# Or if you already have the DataFrame in memory, just assign it:
# table1_cleaned = Table_01_Size_of_UK_Airports-Cleaned

# Standardize airport names
table1_cleaned['airport_name'] = table1_cleaned['airport_name'].str.strip().str.upper()

# %%
import pandas as pd
import numpy as np

# Load your cleaned CSVs
table1_cleaned = pd.read_csv('Table_01_Size_of_UK_Airports-Cleaned.csv')
table10_2 = pd.read_csv('Table_10_2_Domestic_Terminal_Pax-Cleaned.csv')
table12_3 = pd.read_csv('Table_12_3_Route_Pax_By_Airport-Cleaned.csv')

# Standardize airport names
for df, col in [(table1_cleaned, 'airport_name'), (table12_3, 'reporting_airport'), (table10_2, 'airport_name')]:
    df[col] = df[col].str.strip().str.upper()

# %%
# Ensure you have pax_current and pax_5y_prev
table1_cleaned['growth_5y_pct'] = ((table1_cleaned['pax_current'] - table1_cleaned['pax_5y_prev']) / table1_cleaned['pax_5y_prev']) * 100
table1_cleaned['cagr_5y'] = ((table1_cleaned['pax_current'] / table1_cleaned['pax_5y_prev']) ** (1/5) - 1) * 100

# %%
table10_2['scheduled_share'] = (table10_2['scheduled_pax'] / table10_2['total_domestic_pax']) * 100
table10_2['charter_share'] = (table10_2['charter_pax'] / table10_2['total_domestic_pax']) * 100

# Flag high charter risk
table10_2['charter_risk_flag'] = np.where(table10_2['charter_share'] > 50, 'High', 'Low')

# %%
globals().keys()
# Out:
# dict_keys(['__name__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', 'open', '_', '__', '___', '_i', '_ii', '_iii', '_i1', 'pd', 'np', 'plt', '_i2', 'forecast_airports', '_i3', '_i4', 'os', '_4', '_i5', '_i6', '_i7', '_i8'])

# %%
type(forecast_airports)
# Out:
# list

# %%
forecast_airports = pd.DataFrame(forecast_airports)

# %%
forecast_airports.columns
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
forecast_airports.shape
# Out:
# (3, 1)

# %%
forecast_airports
# Out:
#           0
# 0  HEATHROW
# 1     LUTON
# 2  SOUTHEND

# %%
forecast_airports.iloc[:, 0]
# Out:
# 0    HEATHROW
# 1       LUTON
# 2    SOUTHEND
# Name: 0, dtype: object

# %%
import pandas as pd
import numpy as np


table1_data = {
    'airport_name': [
        "HEATHROW", "GATWICK", "MANCHESTER", "STANSTED", "LUTON", 
        "EDINBURGH", "BIRMINGHAM", "BRISTOL", "GLASGOW", 
        "BELFAST INTERNATIONAL", "NEWCASTLE", "LIVERPOOL (JOHN LENNON)"
    ],
    'airport_size': [
        "Large", "Large", "Large", "Large", "Medium", 
        "Medium", "Medium", "Medium", "Medium", 
        "Medium", "Small", "Small"
    ],
    'pax_current': [
        79149042, 40894242, 28077659, 27951116, 16399866, 
        14395463, 11479335, 9911879, 7355987, 
        5956888, 4818885, 4193076
    ],
    'cagr_5y': [
        3.0, 2.5, -0.1, -0.03, 1.2, 
        0.14, 0.5, 2.65, -0.2, 
        -0.1, 0.3, 1.0
    ]
}

table1 = pd.DataFrame(table1_data)
table1['airport_name'] = table1['airport_name'].str.strip().str.upper()


df_routes_data = {
    'reporting_airport': [
        "ABERDEEN", "ABERDEEN", "ABERDEEN", "NEWCASTLE", "LIVERPOOL (JOHN LENNON)"
    ],
    'route': [
        "HEATHROW", "GATWICK", "SUMBURGH", "HEATHROW", "BELFAST INTERNATIONAL"
    ],
    'pax_current': [
        504448, 194377, 100792, 435542, 395118
    ]
}

df_routes = pd.DataFrame(df_routes_data)
df_routes['reporting_airport'] = df_routes['reporting_airport'].str.strip().str.upper()


table12_3 = df_routes.merge(
    table1[['airport_name', 'airport_size', 'cagr_5y', 'pax_current']],
    left_on='reporting_airport',
    right_on='airport_name',
    how='left',
    suffixes=('_route', '_airport')
)


table12_3['route_share_pct'] = (table12_3['pax_current_route'] / table12_3['pax_current_airport']) * 100
table12_3['route_dependency_flag'] = np.where(table12_3['route_share_pct'] > 50, 'High', 'Low')


table12_3['pax_forecast_next_year'] = table12_3['pax_current_route'] * (1 + table12_3['cagr_5y'] / 100)


print(table12_3)
# Out:
#          reporting_airport                  route  pax_current_route  \
# 0                 ABERDEEN               HEATHROW             504448
# 1                 ABERDEEN                GATWICK             194377
# 2                 ABERDEEN               SUMBURGH             100792
# 3                NEWCASTLE               HEATHROW             435542
# 4  LIVERPOOL (JOHN LENNON)  BELFAST INTERNATIONAL             395118
#
#               airport_name airport_size  cagr_5y  pax_current_airport  \
# 0                      NaN          NaN      NaN                  NaN
# 1                      NaN          NaN      NaN                  NaN
# 2                      NaN          NaN      NaN                  NaN
# 3                NEWCASTLE        Small      0.3            4818885.0
# 4  LIVERPOOL (JOHN LENNON)        Small      1.0            4193076.0
#
#    route_share_pct route_dependency_flag  pax_forecast_next_year
# 0              NaN                   Low                     NaN
# 1              NaN                   Low                     NaN
# 2              NaN                   Low                     NaN
# 3         9.038232                   Low              436848.626
# 4         9.423106                   Low              399069.180

# %%
table12_3 = df_routes.merge(
    table1[['airport_name', 'airport_size', 'cagr_5y', 'pax_current']],
    left_on='reporting_airport',
    right_on='airport_name',
    how='left',
    suffixes=('_route', '_airport')
)

# %%
print(table12_3.columns)
# Out:
# Index(['reporting_airport', 'route', 'pax_current_route', 'airport_name',
#        'airport_size', 'cagr_5y', 'pax_current_airport'],
#       dtype='object')

# %%
import numpy as np

table12_3['route_share_pct'] = (
    table12_3['pax_current_route'] / table12_3['pax_current_airport']
) * 100

table12_3['route_dependency_flag'] = np.where(
    table12_3['route_share_pct'] > 50, 'High', 'Low'
)

table12_3['pax_forecast_next_year'] = (
    table12_3['pax_current_route'] * (1 + table12_3['cagr_5y']/100)
)

table12_3.rename(columns={'pax_current_route': 'pax_current'}, inplace=True)

# %%
import pandas as pd
import numpy as np

airport_data = [
    ['FARNBOROUGH', 'Small', 0.0, 100.0, 'High'],
    ['PRESTWICK', 'Small', 0.0, 100.0, 'High'],
    ['BIGGIN HILL', 'Small', 0.0, 100.0, 'High'],
    ['SOUTHEND', 'Small', 22.413793, 77.586207, 'High'],
    ['SUMBURGH', 'Small', 79.131811, 20.868189, 'Low'],
    ['HUMBERSIDE', 'Small', 83.150206, 16.849794, 'Low'],
    ['TEESSIDE INTERNATIONAL AIRPORT', 'Small', 92.980257, 7.019743, 'Low'],
    ['BOURNEMOUTH', 'Small', 96.310495, 3.689505, 'Low'],
    ['CARDIFF WALES', 'Small', 96.637005, 3.362995, 'Low'],
    ['ABERDEEN', 'Small', 97.228574, 2.771426, 'Low']
]

table1 = pd.DataFrame(airport_data, columns=['airport_name','airport_size','scheduled_share','charter_share','charter_risk_flag'])

table1['airport_name'] = table1['airport_name'].str.strip().str.upper()

# %%
route_data = [
    ['ABERDEEN', 'HEATHROW', 504448, 42.446339],
    ['ABERDEEN', 'GATWICK', 194377, 16.355684],
    ['ABERDEEN', 'SUMBURGH', 100792, 8.481055],
    ['ALDERNEY', 'GUERNSEY', 32228, 65.046623],
    ['ALDERNEY', 'SOUTHAMPTON', 17214, 34.743471],
    ['TIREE', 'GLASGOW', 11167, 95.387375],
    ['TIREE', 'OBAN (NORTH CONNEL)', 251, 2.144016],
    ['WICK JOHN O GROATS', 'ABERDEEN', 10674, 99.682480],
    ['WICK JOHN O GROATS', 'FARNBOROUGH', 34, 0.317520]
]

df_routes = pd.DataFrame(route_data, columns=['reporting_airport','route','pax_current_route','route_share_pct'])

df_routes['reporting_airport'] = df_routes['reporting_airport'].str.strip().str.upper()

# %%
table12_3 = df_routes.merge(
    table1[['airport_name','airport_size']],
    left_on='reporting_airport',
    right_on='airport_name',
    how='left'
)

table12_3['route_dependency_flag'] = np.where(table12_3['route_share_pct'] > 50, 'High', 'Low')

table12_3 = table12_3.drop(columns=['airport_name'])

table12_3
# Out:
#     reporting_airport                route  pax_current_route  \
# 0            ABERDEEN             HEATHROW             504448
# 1            ABERDEEN              GATWICK             194377
# 2            ABERDEEN             SUMBURGH             100792
# 3            ALDERNEY             GUERNSEY              32228
# 4            ALDERNEY          SOUTHAMPTON              17214
# 5               TIREE              GLASGOW              11167
# 6               TIREE  OBAN (NORTH CONNEL)                251
# 7  WICK JOHN O GROATS             ABERDEEN              10674
# 8  WICK JOHN O GROATS          FARNBOROUGH                 34
#
#    route_share_pct airport_size route_dependency_flag
# 0        42.446339        Small                   Low
# 1        16.355684        Small                   Low
# 2         8.481055        Small                   Low
# 3        65.046623          NaN                  High
# 4        34.743471          NaN                   Low
# 5        95.387375          NaN                  High
# 6         2.144016          NaN                   Low
# 7        99.682480          NaN                  High
# 8         0.317520          NaN                   Low

# %%
cagr_data = {
    'ABERDEEN': 5.0,
    'ALDERNEY': 2.0,
    'TIREE': 1.5,
    'WICK JOHN O GROATS': 3.0
}

table12_3['cagr_5y'] = table12_3['reporting_airport'].map(cagr_data)

# %%
table12_3['pax_forecast_next_year'] = table12_3['pax_current_route'] * (1 + table12_3['cagr_5y']/100)

# %%
table12_3[['reporting_airport', 'route', 'pax_current_route', 'cagr_5y', 'pax_forecast_next_year', 'route_dependency_flag']]
# Out:
#     reporting_airport                route  pax_current_route  cagr_5y  \
# 0            ABERDEEN             HEATHROW             504448      5.0
# 1            ABERDEEN              GATWICK             194377      5.0
# 2            ABERDEEN             SUMBURGH             100792      5.0
# 3            ALDERNEY             GUERNSEY              32228      2.0
# 4            ALDERNEY          SOUTHAMPTON              17214      2.0
# 5               TIREE              GLASGOW              11167      1.5
# 6               TIREE  OBAN (NORTH CONNEL)                251      1.5
# 7  WICK JOHN O GROATS             ABERDEEN              10674      3.0
# 8  WICK JOHN O GROATS          FARNBOROUGH                 34      3.0
#
#    pax_forecast_next_year route_dependency_flag
# 0              529670.400                   Low
# 1              204095.850                   Low
# 2              105831.600                   Low
# 3               32872.560                  High
# 4               17558.280                   Low
# 5               11334.505                  High
# 6                 254.765                   Low
# 7               10994.220                  High
# 8                  35.020                   Low

# %%
total_forecast_per_airport = table12_3.groupby('reporting_airport')['pax_forecast_next_year'].sum().reset_index()
total_forecast_per_airport.rename(columns={'pax_forecast_next_year':'total_pax_airport_forecast'}, inplace=True)

# %%
table12_3 = table12_3.merge(total_forecast_per_airport, on='reporting_airport', how='left')

# %%
table12_3['route_share_pct_forecast'] = (table12_3['pax_forecast_next_year'] / table12_3['total_pax_airport_forecast']) * 100

# %%
table12_3['route_dependency_flag_forecast'] = np.where(table12_3['route_share_pct_forecast'] > 50, 'High', 'Low')

# %%
table12_3[['reporting_airport', 'route', 'pax_current_route', 'pax_forecast_next_year',
           'total_pax_airport_forecast', 'route_share_pct_forecast', 'route_dependency_flag_forecast']]
# Out:
#     reporting_airport                route  pax_current_route  \
# 0            ABERDEEN             HEATHROW             504448
# 1            ABERDEEN              GATWICK             194377
# 2            ABERDEEN             SUMBURGH             100792
# 3            ALDERNEY             GUERNSEY              32228
# 4            ALDERNEY          SOUTHAMPTON              17214
# 5               TIREE              GLASGOW              11167
# 6               TIREE  OBAN (NORTH CONNEL)                251
# 7  WICK JOHN O GROATS             ABERDEEN              10674
# 8  WICK JOHN O GROATS          FARNBOROUGH                 34
#
#    pax_forecast_next_year  total_pax_airport_forecast  \
# 0              529670.400                   839597.85
# 1              204095.850                   839597.85
# 2              105831.600                   839597.85
# 3               32872.560                    50430.84
# 4               17558.280                    50430.84
# 5               11334.505                    11589.27
# 6                 254.765                    11589.27
# 7               10994.220                    11029.24
# 8                  35.020                    11029.24
#
#    route_share_pct_forecast route_dependency_flag_forecast
# 0                 63.086203                           High
# 1                 24.308763                            Low
# 2                 12.605035                            Low
# 3                 65.183447                           High
# 4                 34.816553                            Low
# 5                 97.801717                           High
# 6                  2.198283                            Low
# 7                 99.682480                           High
# 8                  0.317520                            Low

# %%
table12_3 = table12_3.rename(columns={
    'pax_current_route': 'pax_current',
    'route_share_pct_forecast': 'route_share_pct_next_year',
    'route_dependency_flag_forecast': 'route_dependency_next_year'
})

# %%
years = 5
table12_3['pax_forecast_5y'] = table12_3['pax_current'] * ((1 + table12_3['cagr_5y']/100) ** years)

# %%
table12_3['strategic_route'] = np.where(
    (table12_3['route_dependency_next_year'] == 'High') & 
    (table12_3['cagr_5y'] > 5), 'Yes', 'No'
)

# %%
table12_3.to_csv('forecasted_routes.csv', index=False)

# %%
print(table12_3.columns)
# Out:
# Index(['reporting_airport', 'route', 'pax_current', 'route_share_pct',
#        'airport_size', 'route_dependency_flag', 'cagr_5y',
#        'pax_forecast_next_year', 'total_pax_airport_forecast',
#        'route_share_pct_next_year', 'route_dependency_next_year',
#        'pax_forecast_5y', 'strategic_route'],
#       dtype='object')

# %%
table12_3['pax_forecast_next_year'] = table12_3['pax_current'] * (1 + table12_3['cagr_5y']/100)

# %%
total_pax_forecast = table12_3.groupby('reporting_airport')['pax_forecast_next_year'].sum().reset_index()
total_pax_forecast.rename(columns={'pax_forecast_next_year':'total_pax_airport_forecast'}, inplace=True)
table12_3 = table12_3.merge(total_pax_forecast, on='reporting_airport', how='left')

# %%
import numpy as np

table12_3['pax_forecast_next_year'] = table12_3['pax_current'] * (1 + table12_3['cagr_5y']/100)

# %%
total_pax_forecast = table12_3.groupby('reporting_airport')['pax_forecast_next_year'].sum().reset_index()
total_pax_forecast.rename(columns={'pax_forecast_next_year': 'total_pax_airport_forecast'}, inplace=True)

table12_3 = table12_3.merge(total_pax_forecast, on='reporting_airport', how='left')

# %%
table12_3['route_share_pct_next_year'] = (table12_3['pax_forecast_next_year'] / table12_3['total_pax_airport_forecast']) * 100

# %%
table12_3['route_dependency_next_year'] = np.where(table12_3['route_share_pct_next_year'] > 50, 'High', 'Low')

# %%
if 'total_pax_airport_forecast' in table12_3.columns:
    table12_3 = table12_3.drop(columns=['total_pax_airport_forecast'])

table12_3 = table12_3.merge(
    total_pax_forecast,
    on='reporting_airport',
    how='left'
)

# %%
table12_3 = table12_3.merge(
    total_pax_forecast,
    on='reporting_airport',
    how='left',
    suffixes=('', '_forecast') 
)

# %%
table12_3['pax_forecast_5y'] = table12_3['pax_current'] * (1 + table12_3['cagr_5y']/100) ** 5

# %%
table12_3['strategic_route'] = np.where(
    (table12_3['route_share_pct_next_year'] > 30) & 
    (table12_3['pax_forecast_5y'] > 100000),
    'Yes', 
    'No'
)

# %%
airport_summary = table12_3.groupby('reporting_airport').agg({
    'pax_forecast_next_year':'sum',
    'pax_forecast_5y':'sum'
}).reset_index()

# %%
high_dependency_routes = table12_3[table12_3['route_dependency_next_year'] == 'High']
strategic_routes = table12_3[table12_3['strategic_route'] == 'Yes']

# %%
airport_forecast_summary = table12_3.groupby('reporting_airport').agg({
    'pax_forecast_next_year': 'sum',
    'pax_forecast_5y': 'sum'
}).reset_index()

# %%
top_routes = table12_3.sort_values('pax_forecast_5y', ascending=False).head(10)

# %%
import matplotlib.pyplot as plt

plt.bar(airport_forecast_summary['reporting_airport'], airport_forecast_summary['pax_forecast_5y'])
plt.xticks(rotation=90)
plt.ylabel('Forecasted Passengers in 5 Years')
plt.title('Airport 5-Year Passenger Forecast')
plt.show()

# %%
table12_3['route_dependency_next_year'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>
